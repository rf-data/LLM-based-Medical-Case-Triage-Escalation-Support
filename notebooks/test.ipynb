# %%
# load df
import pandas as pd

path_1 = "/home/robfra/0_Portfolio_Projekte/LLM/data/data_processed/reports/2026-01-22_15:12:09_llm_v3_df.csv"
path_2 = "/home/robfra/0_Portfolio_Projekte/LLM/data/data_processed/reports/2026-01-22_15:12:09_llm_v3_df.csv"
path_3 = "/home/robfra/0_Portfolio_Projekte/LLM/data/data_processed/reports/2026-01-22_15:12:09_llm_v3_df.csv"

df = pd.read_csv(path_1, index_col=0)
df_slim = df.drop(columns=["report_text", "comment", "case_id"])
df_grouped = df_slim.groupby(["domain", "clarity"])[["expected_action", "pred_llm_v3 (batch_size=5)"]]   #.count()

# print(df_slim.head(5), "\n")
print(df_grouped.value_counts())   # .head())
# Out:
# domain   clarity    expected_action  pred_llm_v3 (batch_size=5)
# psych    ambiguous  escalation       True                          40
#                     no_escalation    True                          40
#          clear      escalation       True                          40
#                     no_escalation    True                          40
# somatic  ambiguous  escalation       True                          40
#                     no_escalation    True                          40
#          clear      escalation       True                          40
#                     no_escalation    True                          40
# Name: count, dtype: int64

# %% [markdown]
# # Outputs
# ## baseline
#
# ---
#
# ## LLM run #1
#
#
# ---
#
# ## LLM run #2 (AND version)
# ```
# domain   clarity    expected_action  pred_llm_v3
# psych    ambiguous  escalation       True          40
#                     no_escalation    True          40
#          clear      escalation       True          40
#                     no_escalation    True          40
# somatic  ambiguous  escalation       True          40
#                     no_escalation    True          40
#          clear      escalation       True          40
#                     no_escalation    True          40
# ```
#
# ---
#
# ##
